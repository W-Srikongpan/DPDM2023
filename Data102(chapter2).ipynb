# %% [markdown]
# <a href="https://colab.research.google.com/github/W-Srikongpan/DPDM2023/blob/main/Data102(chapter2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading the data
#
# 25 july 🥳
#
# - directly upload
# - mounting Gdrive

# %% [markdown]
# ##Directly upload (temporary)

# %% [markdown]
# import file csv and read file

# %%
import pandas

# %%
table1 = pandas.read_csv('/content/csv')
# read data csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-292329155bb6> in <cell line: 1>()
# ----> 1 table1 = pandas.read_csv('/content/csv')
#       2 # read data csv
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
table1

# %%
table1.shape
# size data 9*9

# %% [markdown]
# ##Mountingcolab with google drive

# %%
# mountingcolab with google drive
from google.colab import drive
drive.mount('/content/drive')
# connect google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
table_frome_drive = pandas.read_csv('/content/drive/MyDrive/DPDM2023_DATA/csv')
# read data csv from google drive

# %%
table_frome_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 70                17
# 7        May   2566                101                26
# 8       june   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# #1) Eyesball the Data

# %%
table_frome_drive.describe()
# describe data
# Out:
#              Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# count     9.000000           9.000000          9.000000              9.000000
# mean   2565.666667          94.444444         20.444444             35.222222
# std       0.500000           9.658042          3.244654             10.521143
# min    2565.000000          70.000000         17.000000             27.000000
# 25%    2565.000000          94.000000         18.000000             28.000000
# 50%    2566.000000          95.000000         20.000000             30.000000
# 75%    2566.000000         100.000000         22.000000             39.000000
# max    2566.000000         101.000000         26.000000             57.000000
#
#        Amount_ Personalleave  Amount_ Day_Personalleave  \
# count               9.000000                   9.000000
# mean                1.666667                   2.888889
# std                 1.000000                   1.746027
# ...

# %%
table_frome_drive.head()
# show top 5 data 0 to 4
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
#
#    Amount_ Vacationleave  Amount_ Day_Vacationleave
# 0                     35                       57.0
# 1                     31                       47.0
# ...

# %%
table_frome_drive.tail()
# show last 5
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 6     April   2566                 70                17                    29
# 7       May   2566                101                26                    47
# 8      june   2566                101                25                    39
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 4                      2                        5.0                     32
# 5                      2                        4.0                     47
# 6                      1                        1.0                     32
# 7                      1                        2.0                     40
# 8                      2                        3.0                     34
#
#    Amount_ Day_Vacationleave
# ...

# %%
table_frome_drive.head(7)
# show top 7 data 0 to 6
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 70                17
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
# ...

# %% [markdown]
# ##Data Selection (indexing and slicing)

# %% [markdown]
# ### table view

# %%
table_frome_drive['Amount_Government'][2] #indexing
# Out:
# 94

# %%
table_frome_drive['Amount_Government'][:2] #row slic
# Out:
# 0    95
# 1    95
# Name: Amount_Government, dtype: int64

# %%
new_table = table_frome_drive[['Amount_Government','Amount_Day_Sickleave']]

# %%
new_table
# Out:
#    Amount_Government  Amount_Day_Sickleave
# 0                 95                    28
# 1                 95                    57
# 2                 94                    27
# 3                 94                    27
# 4                100                    30
# 5                100                    33
# 6                 84                    29
# 7                101                    47
# 8                130                    39

# %% [markdown]
# ###array view

# %%
table_frome_drive.iloc[2,2] #indexing
# Out:
# 94

# %%
table_frome_drive.iloc[2:8,2:8:2] #slicing
# Out:
#    Amount_Government  Amount_Day_Sickleave  Amount_ Day_Personalleave
# 2                 94                    27                        4.5
# 3                 94                    27                        4.5
# 4                100                    30                        5.0
# 5                100                    33                        4.0
# 6                 84                    29                        1.0
# 7                101                    47                        2.0

# %% [markdown]
# ###assign value to pandas dataFrame

# %% [markdown]
# 1. standard method

# %%
table_frome_drive[6,'Amount_Government'] = 83

# %%
table_frome_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 83                17
# 7        May   2566                101                26
# 8       june   2566                130                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# 2. table view

# %%
table_frome_drive['Amount_Government'][6] = 84
# Out:
# <ipython-input-81-3599a03eb4eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_frome_drive['Amount_Government'][6] = 84

# %%
table_frome_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 84                17
# 7        May   2566                101                26
# 8       june   2566                130                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# 3. array view

# %%
table_frome_drive.iloc[-3,2] = 83

# %%
table_frome_drive.iloc[-1,2] = 130

# %%
table_frome_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 83                17
# 7        May   2566                101                26
# 8       june   2566                130                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# #2) Boxplot

# %%
from matplotlib import pyplot as plt

# %%
table_frome_drive['Amount_Government']
# Out:
# 0     95
# 1     95
# 2     94
# 3     94
# 4    100
# 5    100
# 6     83
# 7    101
# 8    130
# Name: Amount_Government, dtype: int64

# %%
plt.boxplot(table_frome_drive['Amount_Government'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a803a37d750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a803a37f0a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a803a37e9e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a803a37f5e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a803a37f880>],
#  'means': []}

# %% [markdown]
# ##take values from the boxplot

# %%
boxplot_output = plt.boxplot(table_frome_drive['Amount_Government'])

# %%
boxplot_output #Dic
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a803a1f4ee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a803a1f5420>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a803a1f4c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a803a1f5990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a803a1f5c30>],
#  'means': []}

# %%
boxplot_output['fliers'] #Dic

# %%
boxplot_output['fliers'][0] #list in Dic

# %%
boxplot_output['fliers'][0].get_ydata() #Array
# Out:
# array([ 83, 130])

# %%
boxplot_output['fliers'][0].get_ydata()[0] #Dic,Array
# Out:
# 83

# %%
boxplot_output['fliers'][0].get_ydata()[1]
# Out:
# 130

# %% [markdown]
# #Querying and Filtering

# %% [markdown]
# ```python
# DataFrame[list_of_logics] #len(list_of_logics) = len(DataFrame)
# ```

# %%
table_frome_drive[[False,False,False,True,False,True,False,False,False]] #i want Jan and Mar
# Out:
#     Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 3  January   2566                 94                18                    27
# 5    March   2566                100                22                    33
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 3                      3                        4.5                     47
# 5                      2                        4.0                     47
#
#    Amount_ Day_Vacationleave
# 3                       69.5
# 5                       75.0

# %% [markdown]
# ###Create list_of_logics

# %%
table_frome_drive['Amount_Sickleave'] == 20
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# Name: Amount_Sickleave, dtype: bool

# %%
table_frome_drive[table_frome_drive['Amount_Sickleave'] == 20]
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 1  Novembers   2565                 95                20
# 4   February   2566                100                20
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 1                    57                      0                        0.0
# 4                    30                      2                        5.0
#
#    Amount_ Vacationleave  Amount_ Day_Vacationleave
# 1                     31                       47.0
# 4                     32                       60.0

# %%
boxplot_output = plt.boxplot(table_frome_drive['Amount_Government'], whis = 2)

# %%
boxplot_output = plt.boxplot(table_frome_drive['Amount_Government'], whis = 2, vert = False)

# %% [markdown]
# #Quiz 3 🔥

# %% [markdown]
# filter out the outliers rows ($'Amount\_Government'$)

# %%
table_frome_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 83                17
# 7        May   2566                101                26
# 8       june   2566                130                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# delete oulier

# %%
table_frome_drive[(table_frome_drive['Amount_Government'] > boxplot_output['fliers'][0].get_ydata()[0]) & (table_frome_drive['Amount_Government'] < boxplot_output['fliers'][0].get_ydata()[1])]
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 7        May   2566                101                26
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
# ...

# %% [markdown]
# answer quiz3

# %%
boxplot_output['whiskers'][0].get_ydata().min()
# Out:
# 94.0

# %%
boxplot_output['whiskers'][1].get_ydata().max()
# Out:
# 101.0

# %%
table_frome_drive[(table_frome_drive['Amount_Government'] <= boxplot_output['whiskers'][1].get_ydata().max()) &
                  (table_frome_drive['Amount_Government'] >= boxplot_output['whiskers'][0].get_ydata().min()) ]
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1  Novembers   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4   February   2566                100                20
# 5      March   2566                100                22
# 7        May   2566                101                26
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
# ...

# %% [markdown]
# #4) Plot all datapoints (depend on data type)

# %% [markdown]
# ## Time Series data is the data that has time related which tells order of the data

# %%
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Government'])

# %%
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Government'],'o:r')

# %%
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Government'],'or')

# %%
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Government'],'or')
plt.title('Monthly Amount_Government')
# Out:
# Text(0.5, 1.0, 'Monthly Amount_Government')

# %%
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Government'],'o-r')
plt.title('Monthly Amount_Government')
plt.xlabel('month')
plt.ylabel ('Amount_Government')
plt.xticks (range(len(table_frome_drive)), ['Oct', 'Nov', 'Dec','Jan','Feb','Mar','Apr','May','Jun']);

# %%
label = ['Oct', 'Nov', 'Dec','Jan','Feb','Mar','Apr','May','Jun']
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Government'],'o--r')
plt.title('Monthly Amount_Government')
plt.xlabel('month')
plt.ylabel ('Amount_Government')
plt.xticks (range(len(table_frome_drive)), label);

# %% [markdown]
# compare 2 columns

# %%
label = ['Oct', 'Nov', 'Dec','Jan','Feb','Mar','Apr','May','Jun']
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Government'],'o--b', label = 'Government')
plt.plot(range(len(table_frome_drive)),table_frome_drive['Amount_Sickleave'],'o--r',label = 'Sickleave') # plot more data here
plt.title('Monthly Amount_Government vs Amount_Sickleave')
plt.xlabel('month')
plt.ylabel('number of people')
plt.xticks(range(len(table_frome_drive)), label)
plt.legend();

# %% [markdown]
# ##Bar chart

# %%
plt.bar(range(len(table_frome_drive)),table_frome_drive['Amount_Sickleave'] , label = 'Sickleave')
plt.title('Monthly Amount_Sickleave by months')
plt.xlabel('month')
plt.ylabel('number of sick leave')
plt.xticks(range(len(table_frome_drive)), label)
plt.legend() ;

# %% [markdown]
# ## Stacked Barchart

# %%
label = ['Oct', 'Nov', 'Dec','Jan','Feb','Mar','Apr','May','Jun']
plt.bar(range(len(table_frome_drive)),table_frome_drive['Amount_Sickleave'], color = 'b' , label = 'Sickleave')
plt.bar(range(len(table_frome_drive)),table_frome_drive['Amount_ Personalleave'],bottom=table_frome_drive['Amount_Sickleave'], color = 'r' , label = 'Personal leave')
plt.bar(range(len(table_frome_drive)),table_frome_drive['Amount_ Vacationleave'],bottom=table_frome_drive['Amount_Sickleave'] + table_frome_drive['Amount_ Personalleave'], color = 'g' , label = 'Vacation leave')
plt.xticks(range(len(table_frome_drive)),label)
plt.grid(True,axis='y')
plt.legend() ;

# %% [markdown]
# ## grouped Barchart

# %%
import numpy as np
width = 0.2
plt.bar(range(len(table_frome_drive)), table_frome_drive['Amount_Sickleave'],width,color='g',label='sick leave')
plt.bar(np.array(range(len(table_frome_drive)))-width, table_frome_drive['Amount_ Personalleave'],width,color='r',label='Personal leave')
plt.bar(np.array(range(len(table_frome_drive)))+width, table_frome_drive['Amount_ Vacationleave'],width,color='b',label='Vacation leave')
plt.legend();

# %% [markdown]
# HW 3 select your data and do step 1 to 4 (Eyesball the Data,Statical deacriptive, Boxplot(filter out outlier), plot the dataset with plot, stacked barchart, grouped barchart)

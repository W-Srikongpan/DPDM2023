# %% [markdown]
# <a href="https://colab.research.google.com/github/W-Srikongpan/DPDM2023/blob/main/Data102(chapter2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading the data
#
# 25 july 🥳
#
# - directly upload
# - mounting Gdrive

# %% [markdown]
# ##Directly upload (temporary)

# %%
import pandas

# %%
table1 = pandas.read_csv('/content/csv')

# %%
table1
# Out:
#        Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0      ตุลาคม   2565                 95                18
# 1   พฤศจิกายน   2565                 95                20
# 2     ธันวาคม   2565                 94                18
# 3      มกราคม   2566                 94                18
# 4  กุมภาพันธ์   2566                100                20
# 5      มีนาคม   2566                100                22
# 6      เมษายน   2566                100                17
# 7     พฤษภาคม   2566                101                26
# 8    มิถุนายน   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %%
table1.shape
# Out:
# (9, 9)

# %%
# mountingcolab with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
table_frome_drive = pandas.read_csv('/content/drive/MyDrive/DPDM2023_DATA/csv')

# %%
table_frome_drive
# Out:
#        Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0      ตุลาคม   2565                 95                18
# 1   พฤศจิกายน   2565                 95                20
# 2     ธันวาคม   2565                 94                18
# 3      มกราคม   2566                 94                18
# 4  กุมภาพันธ์   2566                100                20
# 5      มีนาคม   2566                100                22
# 6      เมษายน   2566                100                17
# 7     พฤษภาคม   2566                101                26
# 8    มิถุนายน   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# ##1) Eyesball the Data

# %%
table_frome_drive.describe()
# Out:
#              Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# count     9.000000           9.000000          9.000000              9.000000
# mean   2565.666667          97.777778         20.444444             35.222222
# std       0.500000           3.153481          3.244654             10.521143
# min    2565.000000          94.000000         17.000000             27.000000
# 25%    2565.000000          95.000000         18.000000             28.000000
# 50%    2566.000000         100.000000         20.000000             30.000000
# 75%    2566.000000         100.000000         22.000000             39.000000
# max    2566.000000         101.000000         26.000000             57.000000
#
#        Amount_ Personalleave  Amount_ Day_Personalleave  \
# count               9.000000                   9.000000
# mean                1.666667                   2.888889
# std                 1.000000                   1.746027
# ...

# %%
table_frome_drive.head()
# Out:
#        Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0      ตุลาคม   2565                 95                18
# 1   พฤศจิกายน   2565                 95                20
# 2     ธันวาคม   2565                 94                18
# 3      มกราคม   2566                 94                18
# 4  กุมภาพันธ์   2566                100                20
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
#
#    Amount_ Vacationleave  Amount_ Day_Vacationleave
# 0                     35                       57.0
# 1                     31                       47.0
# ...

# %%
table_frome_drive.tail()
# Out:
#        Month_  Year_  Amount_Government  Amount_Sickleave  \
# 4  กุมภาพันธ์   2566                100                20
# 5      มีนาคม   2566                100                22
# 6      เมษายน   2566                100                17
# 7     พฤษภาคม   2566                101                26
# 8    มิถุนายน   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 4                    30                      2                        5.0
# 5                    33                      2                        4.0
# 6                    29                      1                        1.0
# 7                    47                      1                        2.0
# 8                    39                      2                        3.0
#
#    Amount_ Vacationleave  Amount_ Day_Vacationleave
# 4                     32                       60.0
# 5                     47                       75.0
# ...

# %%
table_frome_drive.head(7)
# Out:
#        Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0      ตุลาคม   2565                 95                18
# 1   พฤศจิกายน   2565                 95                20
# 2     ธันวาคม   2565                 94                18
# 3      มกราคม   2566                 94                18
# 4  กุมภาพันธ์   2566                100                20
# 5      มีนาคม   2566                100                22
# 6      เมษายน   2566                100                17
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/W-Srikongpan/DPDM2023/blob/main/MIDTERM%20EXAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive # conect google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from google.colab import drive # conect google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
excel_file_path = '/content/drive/MyDrive/DPDM2023_DATA/ectreport66.xlsx'
sheet_name1 = 'Candidate_Constituency'
df_candidate = pd.read_excel(excel_file_path , sheet_name = sheet_name1)
df_candidate = pd.DataFrame(df_candidate)

# %%
sheet_name2 = 'result_constituencies_Candidate'
df_result_constituencies = pd.read_excel(excel_file_path , sheet_name = sheet_name2)
df_result_constituencies = pd.DataFrame(df_result_constituencies)

# %%
sheet_name3 = 'info_party_overview'
df_info_party_overview = pd.read_excel(excel_file_path , sheet_name = sheet_name3)
df_info_party_overview = pd.DataFrame(df_info_party_overview)

# %% [markdown]
# # 1. Create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10

# %% [markdown]
# ##create data

# %%
#mp_app_name = name
# mp_app_party_id = parties
# mp_app_id = ID constituency candidate
del df_candidate['image_url']
del df_candidate['mp_app_no']
df_candidate
# Out:
#      mp_app_id             mp_app_name  mp_app_party_id
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์              712
# 3     ACR_1_12          นายไสว ผลาวงศ์              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์              761
# ...        ...                     ...              ...
# 4776   YST_3_5       นายธนพัฒน์ ศรีชนะ              709
# 4777   YST_3_6        นายพิทยา พาลุสุข              763
# 4778   YST_3_7      นายศรายุทธ สุดสวาท              712
# 4779   YST_3_8    นางสาวสุนันทา สีชมภู              769
# 4780   YST_3_9        นายณัฐพล ศรีอุบล              726
#
# [4781 rows x 3 columns]

# %%
# party_id
# mp_app_vote
# mp_app_rank
df_result_constituencies
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id
# 0          706
# 1          709
# 2          712
# 3          742
# 4          761
# ...        ...
# ...

# %%
del common_data1['logo_url']
common1 = df_result_constituencies.merge(df_info_party_overview, left_on='party_id' ,right_on = 'id' )
common1
# Out:
#      cons_id  mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1    ACR_1_1            9          459              0.43477
# 1      BKK_1    BKK_1_9            7         1247              1.32088
# 2     BKK_10   BKK_10_1            7          751              0.72144
# 3     BKK_11  BKK_11_10            9          402              0.39176
# 4     BKK_12  BKK_12_14            7         1077              1.01212
# ...      ...        ...          ...          ...                  ...
# 4776   SRN_3   SRN_3_11            9          208              0.21936
# 4777   SRN_4   SRN_4_12           12          154              0.16518
# 4778  UBN_11  UBN_11_12           12          168              0.17959
# 4779  UBN_10   UBN_10_1            1        63127             62.27446
# 4780   UBN_3    UBN_3_3            1        31218             30.10211
#
#       party_id   id  party_no            name  abbr    color  \
# ...

# %% [markdown]
# ##Comon data

# %%
common_data1 = df_candidate.merge(common1, on= 'mp_app_id',how='inner' )
common_data1
# Out:
#      mp_app_id             mp_app_name  mp_app_party_id cons_id  mp_app_rank  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว              706   ACR_1            9
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล              709   ACR_1            1
# 2     ACR_1_11     นายการันต์ ลุนพันธ์              712   ACR_1           13
# 3     ACR_1_12          นายไสว ผลาวงศ์              742   ACR_1           12
# 4     ACR_1_13        นายสงบ โสภิพันธ์              761   ACR_1           11
# ...        ...                     ...              ...     ...          ...
# 4776   YST_3_5       นายธนพัฒน์ ศรีชนะ              709   YST_3            1
# 4777   YST_3_6        นายพิทยา พาลุสุข              763   YST_3            7
# 4778   YST_3_7      นายศรายุทธ สุดสวาท              712   YST_3            9
# 4779   YST_3_8    นางสาวสุนันทา สีชมภู              769   YST_3           11
# 4780   YST_3_9        นายณัฐพล ศรีอุบล              726   YST_3            3
#
# ...

# %% [markdown]
# ##sort

# %%
from collections import Counter
count = Counter(common_data1['cons_id'])
count
# Out:
# Counter({'ACR_1': 13,
#          'ACR_2': 12,
#          'ATG_1': 8,
#          'ATG_2': 9,
#          'AYA_1': 10,
#          'AYA_2': 10,
#          'AYA_3': 10,
#          'AYA_4': 9,
#          'AYA_5': 13,
#          'BKK_1': 15,
#          'BKK_10': 16,
#          'BKK_11': 13,
#          'BKK_12': 16,
#          'BKK_13': 16,
#          'BKK_14': 15,
#          'BKK_15': 16,
#          'BKK_16': 16,
#          'BKK_17': 18,
#          'BKK_18': 16,
#          'BKK_19': 17,
#          'BKK_2': 15,
#          'BKK_20': 15,
#          'BKK_21': 15,
#          'BKK_22': 14,
#          'BKK_23': 17,
#          'BKK_24': 14,
#          'BKK_25': 16,
#          'BKK_26': 12,
#          'BKK_27': 15,
#          'BKK_28': 11,
#          'BKK_29': 12,
#          'BKK_3': 17,
#          'BKK_30': 14,
#          'BKK_31': 15,
#          'BKK_32': 16,
#          'BKK_33': 16,
#          'BKK_4': 15,
#          'BKK_5': 14,
#          'BKK_6': 16,
#          'BKK_7': 15,
# ...

# %%
name = []
for y in count.keys():
    name.append(y)
name.sort()
print(name)
# Out:
# ['ACR_1', 'ACR_2', 'ATG_1', 'ATG_2', 'AYA_1', 'AYA_2', 'AYA_3', 'AYA_4', 'AYA_5', 'BKK_1', 'BKK_10', 'BKK_11', 'BKK_12', 'BKK_13', 'BKK_14', 'BKK_15', 'BKK_16', 'BKK_17', 'BKK_18', 'BKK_19', 'BKK_2', 'BKK_20', 'BKK_21', 'BKK_22', 'BKK_23', 'BKK_24', 'BKK_25', 'BKK_26', 'BKK_27', 'BKK_28', 'BKK_29', 'BKK_3', 'BKK_30', 'BKK_31', 'BKK_32', 'BKK_33', 'BKK_4', 'BKK_5', 'BKK_6', 'BKK_7', 'BKK_8', 'BKK_9', 'BKN_1', 'BKN_2', 'BKN_3', 'BRM_1', 'BRM_10', 'BRM_2', 'BRM_3', 'BRM_4', 'BRM_5', 'BRM_6', 'BRM_7', 'BRM_8', 'BRM_9', 'CBI_1', 'CBI_10', 'CBI_2', 'CBI_3', 'CBI_4', 'CBI_5', 'CBI_6', 'CBI_7', 'CBI_8', 'CBI_9', 'CCO_1', 'CCO_2', 'CCO_3', 'CCO_4', 'CMI_1', 'CMI_10', 'CMI_2', 'CMI_3', 'CMI_4', 'CMI_5', 'CMI_6', 'CMI_7', 'CMI_8', 'CMI_9', 'CNT_1', 'CNT_2', 'CPM_1', 'CPM_2', 'CPM_3', 'CPM_4', 'CPM_5', 'CPM_6', 'CPM_7', 'CPN_1', 'CPN_2', 'CPN_3', 'CRI_1', 'CRI_2', 'CRI_3', 'CRI_4', 'CRI_5', 'CRI_6', 'CRI_7', 'CTI_1', 'CTI_2', 'CTI_3', 'KBI_1', 'KBI_2', 'KBI_3', 'KKN_1', 'KKN_10', 'KKN_11', 'KKN_
# ...

# %% [markdown]
# test read 'name'

# %%
common_data1[common_data1['cons_id']== 'ACR_1']
# Out:
#    mp_app_id                mp_app_name  mp_app_party_id cons_id  mp_app_rank  \
# 0    ACR_1_1      นางสาวปิยะมาศ บัวแก้ว              706   ACR_1            9
# 1   ACR_1_10     นางสุขสมรวย วันทนียกุล              709   ACR_1            1
# 2   ACR_1_11        นายการันต์ ลุนพันธ์              712   ACR_1           13
# 3   ACR_1_12             นายไสว ผลาวงศ์              742   ACR_1           12
# 4   ACR_1_13           นายสงบ โสภิพันธ์              761   ACR_1           11
# 5    ACR_1_2             นายกมล บุญธิมา              769   ACR_1           10
# 6    ACR_1_3        นายบวรศักดิ์ คณาเสน              763   ACR_1            6
# 7    ACR_1_4       นายอิทธิกร สุวะมาตย์              719   ACR_1            8
# 8    ACR_1_5  นางสาวแป้งธนชาภา จันทวารา              701   ACR_1            4
# 9    ACR_1_6          นายประภาส เวชกรณ์              726   ACR_1            3
# 10   ACR_1_7           นายทวีชัย พลธานี              762   ACR_1            7
# ...

# %% [markdown]
# test sorted

# %%
sorted_common_data1 = common_data1[common_data1['cons_id']== 'ACR_1'].sort_values(by = 'mp_app_vote', ascending=False)
Top10 = sorted_common_data1.head(10)
Top10[['mp_app_name','id','name']]
# Out:
#                   mp_app_name   id             name
# 1      นางสุขสมรวย วันทนียกุล  709        ภูมิใจไทย
# 11          นางสมหญิง บัวบุตร  705         เพื่อไทย
# 9           นายประภาส เวชกรณ์  726          ก้าวไกล
# 8   นางสาวแป้งธนชาภา จันทวารา  701     ประชาธิปัตย์
# 12          นายวิชัย บุญเสริฐ  743     พลังประชารัฐ
# 6         นายบวรศักดิ์ คณาเสน  763  รวมไทยสร้างชาติ
# 10           นายทวีชัย พลธานี  762      ไทยสร้างไทย
# 7        นายอิทธิกร สุวะมาตย์  719       เสรีรวมไทย
# 0       นางสาวปิยะมาศ บัวแก้ว  706    ชาติพัฒนากล้า
# 5              นายกมล บุญธิมา  769         ไทยภักดี

# %%
keep = []

for i in range(len(name)):
    x = common_data1[common_data1['cons_id'] == name[i]].sort_values(by = 'mp_app_vote', ascending=False)
    y = x.head(10)
    z= y[['mp_app_name','id','name']]
    keep.append(z)

keep
# Out:
# [                  mp_app_name   id             name
#  1      นางสุขสมรวย วันทนียกุล  709        ภูมิใจไทย
#  11          นางสมหญิง บัวบุตร  705         เพื่อไทย
#  9           นายประภาส เวชกรณ์  726          ก้าวไกล
#  8   นางสาวแป้งธนชาภา จันทวารา  701     ประชาธิปัตย์
#  12          นายวิชัย บุญเสริฐ  743     พลังประชารัฐ
#  6         นายบวรศักดิ์ คณาเสน  763  รวมไทยสร้างชาติ
#  10           นายทวีชัย พลธานี  762      ไทยสร้างไทย
#  7        นายอิทธิกร สุวะมาตย์  719       เสรีรวมไทย
#  0       นางสาวปิยะมาศ บัวแก้ว  706    ชาติพัฒนากล้า
#  5              นายกมล บุญธิมา  769         ไทยภักดี,
#                    mp_app_name   id             name
#  14         นางญาณีนาถ เข็มนาค  709        ภูมิใจไทย
#  13          นายไมตรี แก้วมงคล  726          ก้าวไกล
#  18         นายดะนัย มะหิพันธ์  705         เพื่อไทย
#  24  นางจันทร์เพ็ญ ประเสริฐศรี  743     พลังประชารัฐ
#  20      นายอภิวัฒน์ เงินหมื่น  701     ประชาธิปัตย์
#  17      นางสาวสิริพรรณ อมรสิน  762      ไทยสร้างไทย
# ...

# %% [markdown]
# #2. Create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)

# %% [markdown]
# ##Sort

# %%
keep2 = []

for i in range(len(name)):
    x = common_data1[common_data1['cons_id'] == name[i]].sort_values(by = 'mp_app_vote', ascending=True)
    y = x.head(5)
    z = y[['mp_app_name','id','name']]
    keep2.append(z)

keep2

# %% [markdown]
# #3. Create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.

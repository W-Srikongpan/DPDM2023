# %% [markdown]
# <a href="https://colab.research.google.com/github/W-Srikongpan/DPDM2023/blob/main/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive # conect google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_df = pd.read_csv('/content/drive/MyDrive/DPDM2023_DATA/opendata_unittype-2.csv')
project_df.head()
# Out:
#    row_number               unittype_id                project_id  \
# 0       37586            unittype_35602             project_15270
# 1        9427             unittype_4487              project_1476
# 2       12994            unittype_37624             project_16674
# 3       19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4       10907             unittype_8344              project_2821
#
#                name_th  propertytype_id propertytype_name_en  \
# 0               Studio                2                Condo
# 1              ภัทรสิน                3             Townhome
# 2               Type B                3             Townhome
# 3      ทาวน์โฮมสองชั้น                3             Townhome
# 4  2 Bedroom (ขายแล้ว)                2                Condo
#
#   propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 0                คอนโด                NaN             30.0  3700000.0  ...
# ...

# %% [markdown]
# ###6. What is average price of the property that has usable area (area_usable_min) between 50-100 sqm?

# %%
area_usable = project_df[['area_usable_min','price_min']]

# %%
area_usable = project_df[['area_usable_min','price_min']]
selected_rows = area_usable.loc[(area_usable['area_usable_min'] >= 50) & (area_usable['area_usable_min'] <= 50) ]
a = selected_rows.dropna()

# %%
sum(a['price_min'])
len(a['price_min'])
average = sum(a['price_min'])/len(a['price_min'])
print(f"Average: {average}")
# Out:
# Average: 3607233.537688442

# %%
project_df.describe()

# %%
project_df.isnull()

# %%
project_df.isnull().any()

# %%
project_df.isnull().all() # .all() เอาค่าความจริงใน column มา and กัน

# %% [markdown]
# ##Drop

# %%
project_df.shape
# Out:
# (35123, 28)

# %%
unit_df = pd.read_csv('/content/drive/MyDrive/DPDM2023_DATA/opendata_unittype-2.csv')
unit_df.head()
# Out:
#    row_number               unittype_id                project_id  \
# 0       37586            unittype_35602             project_15270
# 1        9427             unittype_4487              project_1476
# 2       12994            unittype_37624             project_16674
# 3       19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4       10907             unittype_8344              project_2821
#
#                name_th  propertytype_id propertytype_name_en  \
# 0               Studio                2                Condo
# 1              ภัทรสิน                3             Townhome
# 2               Type B                3             Townhome
# 3      ทาวน์โฮมสองชั้น                3             Townhome
# 4  2 Bedroom (ขายแล้ว)                2                Condo
#
#   propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 0                คอนโด                NaN             30.0  3700000.0  ...
# ...

# %%
unit_df.shape
# Out:
# (43374, 28)

# %%
project_df.dropna()
# Out:
# Empty DataFrame
# Columns: [row_number, unittype_id, project_id, name_th, propertytype_id, propertytype_name_en, propertytype_name_th, area_total_min_wa, area_usable_min, price_min, count_airconditioner, count_elevator, count_floor_internal, count_parking, count_room_bath, count_room_bed, count_room_dinning, count_room_guest, count_room_kitchen, count_room_living, count_room_maid, count_room_storage, count_room_utility, date_created, date_updated, source, url_unittype, day]
# Index: []
#
# [0 rows x 28 columns]

# %%
unit_df.dropna()
# Out:
# Empty DataFrame
# Columns: [row_number, unittype_id, project_id, name_th, propertytype_id, propertytype_name_en, propertytype_name_th, area_total_min_wa, area_usable_min, price_min, count_airconditioner, count_elevator, count_floor_internal, count_parking, count_room_bath, count_room_bed, count_room_dinning, count_room_guest, count_room_kitchen, count_room_living, count_room_maid, count_room_storage, count_room_utility, date_created, date_updated, source, url_unittype, day]
# Index: []
#
# [0 rows x 28 columns]

# %%
project_df.dropna(axis=1)
# Out:
#        row_number               unittype_id                project_id  \
# 0           37586            unittype_35602             project_15270
# 1            9427             unittype_4487              project_1476
# 3           19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4           10907             unittype_8344              project_2821
# 5           26056            unittype_22238              project_2742
# ...           ...                       ...                       ...
# 43369        9507             unittype_5086              project_1635
# 43370       23721            unittype_15644              project_6109
# 43371       31551            unittype_21385              project_8392
# 43372       29837            unittype_26243             project_10566
# 43373        9465            unittype_35686             project_15298
#
#                           name_th  propertytype_id propertytype_name_en  \
# ...

# %%
project_df_droped = project_df.dropna(subset=['propertytype_name_en','price_min'])

# %%
project_df.dropna(subset=['propertytype_name_en','price_min']).isnull().any()
# Out:
# row_number              False
# unittype_id             False
# project_id              False
# name_th                 False
# propertytype_id         False
# propertytype_name_en    False
# propertytype_name_th    False
# area_total_min_wa        True
# area_usable_min          True
# price_min               False
# count_airconditioner     True
# count_elevator           True
# count_floor_internal     True
# count_parking            True
# count_room_bath          True
# count_room_bed           True
# count_room_dinning       True
# count_room_guest         True
# count_room_kitchen       True
# count_room_living        True
# count_room_maid          True
# count_room_storage       True
# count_room_utility       True
# date_created            False
# date_updated            False
# source                  False
# url_unittype            False
# day                     False
# dtype: bool

# %%
#update data
project_df.dropna(subset=['propertytype_name_en','price_min'],inplace=True)

# %%
project_df.isnull().any()
# Out:
# row_number              False
# unittype_id             False
# project_id              False
# name_th                 False
# propertytype_id         False
# propertytype_name_en    False
# propertytype_name_th    False
# area_total_min_wa        True
# area_usable_min          True
# price_min               False
# count_airconditioner     True
# count_elevator           True
# count_floor_internal     True
# count_parking            True
# count_room_bath          True
# count_room_bed           True
# count_room_dinning       True
# count_room_guest         True
# count_room_kitchen       True
# count_room_living        True
# count_room_maid          True
# count_room_storage       True
# count_room_utility       True
# date_created            False
# date_updated            False
# source                  False
# url_unittype            False
# day                     False
# dtype: bool

# %% [markdown]
# ## Example

# %% [markdown]
# ###1.
#  remove missing values by dropping column,

# %% [markdown]
# ###2.

# %% [markdown]
# #Replace missing value

# %% [markdown]
# ##Replace missing value with appropriate value(introduce a new class, up to you)

# %% [markdown]
# ##Replace missing value with mean of the sub-group

# %%
set(unit_df['propertytype_name_en'])

# %% [markdown]
# #Concatenate

# %% [markdown]
# ##concatenate table in the Y-axis (add more data point)

# %% [markdown]
# ##concatenate table in the X-axis (adding features to the data)

# %% [markdown]
# ###Ex. map the district from the project table to the unitale

# %%
merged_df = unit_df.merge(project_df,left_on='project_id',right_on='project_id')
merged_df.head()
# Out:
#    row_number_x   unittype_id_x     project_id  name_th_x  propertytype_id_x  \
# 0         37586  unittype_35602  project_15270     Studio                  2
# 1         37586  unittype_35602  project_15270     Studio                  2
# 2         37586  unittype_35602  project_15270     Studio                  2
# 3         37585  unittype_35604  project_15270  2 Bedroom                  2
# 4         37585  unittype_35604  project_15270  2 Bedroom                  2
#
#   propertytype_name_en_x propertytype_name_th_x  area_total_min_wa_x  \
# 0                  Condo                  คอนโด                  NaN
# 1                  Condo                  คอนโด                  NaN
# 2                  Condo                  คอนโด                  NaN
# 3                  Condo                  คอนโด                  NaN
# 4                  Condo                  คอนโด                  NaN
#
#    area_usable_min_x  price_min_x  ...  count_room_kitchen_y  \
# ...

# %%
unit_df['district_name_en'] = unit_df['project_id'].map(project_df.set_index('project_id')['district_name_en'])

# %%
project_df.isnull().any()
# Out:
# row_number              False
# unittype_id             False
# project_id              False
# name_th                 False
# propertytype_id         False
# propertytype_name_en    False
# propertytype_name_th    False
# area_total_min_wa        True
# area_usable_min          True
# price_min               False
# count_airconditioner     True
# count_elevator           True
# count_floor_internal     True
# count_parking            True
# count_room_bath          True
# count_room_bed           True
# count_room_dinning       True
# count_room_guest         True
# count_room_kitchen       True
# count_room_living        True
# count_room_maid          True
# count_room_storage       True
# count_room_utility       True
# date_created            False
# date_updated            False
# source                  False
# url_unittype            False
# day                     False
# dtype: bool

# %% [markdown]
# #Create pandas df & save pandas df

# %% [markdown]
# ##Create table

# %% [markdown]
# ##Dict-Row

# %%
sale = [{'account':'Jones LLC','Jan':150,'Feb':200,'Mar':140},
        {'account':'Alpha Co','Jan':200,'Feb':210,'Mar':215},
        {'account':'Blue Inc','Jan':50,'Feb':90,'Mar':95}
]

sale_tb1 = pd.DataFrame(sale)
sale_tb1
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ##Dict-Column

# %%
sales = { 'account':['Jones LLC','Alpha Co','Blue Inc'],
          'Jan'    :[150,200,50],
          'Feb'    :[200,210,90],
          'Mar'    :[140,215,90]
}
sale_tb2 = pd.DataFrame.from_dict(sales)
sale_tb2
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ##List-Row

# %%
sale = [['Jones LLC',150,200,140],
        ['Alpha Co',200,210,215],
        ['Blue Inc',50,90,90]]
labels = ['account','Jan','Feb','Mar']

sale_tb3 =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-155defce0332> in <cell line: 4>()
#       2         ['Alpha Co',200,210,215],
#       3         ['Blue Inc',50,90,90]]
# ----> 4 labels - ['account','Jan','Feb','Mar']
#
# NameError: name 'labels' is not defined
